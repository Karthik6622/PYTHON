# %% [markdown]
# # singly-Linked-List

# %%
#implement of traversal
class Node:
    def __init__(self,data):
        self.data=data
        self.ref=None
class Linked_list():
    def __init__(self):
        self.head=None
    def traversal(self):
        if self.head is None:
            print("Linked List is empty!!!")
        else:
            n=self.head
            while n is not None:
                print(n.data)
                n=n.ref
ll=Linked_list()
ll.traversal()
# Out:
# Linked List is empty!!!

# %%
#adding element begining of the Linkedlist
class Node:
    def __init__(self,data):
        self.data=data
        self.ref=None
class Linked_list():
    def __init__(self):
        self.head=None
    def traversal(self):
        if self.head is None:
            print("Linked List is empty!!!")
        else:
            n=self.head
            while n is not None:
                print(n.data,"-->",end="")
                n=n.ref
    def add_begin(self,data):
        new_node=Node(data)
        new_node.ref=self.head
        self.head=new_node       
ll=Linked_list()
ll.add_begin(10)
ll.add_begin(20)
ll.add_begin(30)
ll.traversal()
# Out:
# 30 -->20 -->10 -->

# %%
#adding the element end of the linked list
class Node:
    def __init__(self,data):
        self.data=data
        self.ref=None
class Linked_list():
    def __init__(self):
        self.head=None
    def traversal(self):
        if self.head is None:
            print("Linked List is empty!!!")
        else:
            n=self.head
            while n is not None:
                print(n.data,"-->",end="")
                n=n.ref
    def add_begin(self,data):
        new_node=Node(data)
        new_node.ref=self.head
        self.head=new_node       
    def add_end(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
        else:
            n=self.head
            while(n.ref is not None):
                n=n.ref
            n.ref=new_node
ll=Linked_list()
ll.add_end(100)
ll.add_end(200)
ll.add_end(300)
ll.traversal()
# Out:
# 100 -->200 -->300 -->

# %%
#Insert node inbetween the Linked List
#insert elemnt after we mentioned node
class Node:
    def __init__(self,data):
        self.data=data
        self.ref=None
class Linked_list():
    def __init__(self):
        self.head=None
    def traversal(self):
        if self.head is None:
            print("Linked List is empty!!!")
        else:
            n=self.head
            while n is not None:
                print(n.data,"-->",end="")
                n=n.ref
    def add_begin(self,data):
        new_node=Node(data)
        new_node.ref=self.head
        self.head=new_node       
    def add_end(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
        else:
            n=self.head
            while(n.ref is not None):
                n=n.ref
            n.ref=new_node
    def after_node(self,data,x):
        if self.head is None:
            print("Linked list is empty!!!")
            return
        n=self.head
        while n is not None:
            if n.data==x:
                break
            else:
                n=n.ref
        if n is None:
            print("Node is not pesent in LL")
        else:
            new_node=Node(data)
            new_node.ref=n.ref
            n.ref=new_node
                    
ll=Linked_list()
ll.add_begin(100)
ll.after_node(200,100)
ll.after_node(300,100)
ll.traversal()
# Out:
# 100 -->300 -->200 -->

# %%
#Insert node inbetween the Linked List
#insert elemnt before we mentioned node
class Node:
    def __init__(self,data):
        self.data=data
        self.ref=None
class Linked_list():
    def __init__(self):
        self.head=None
    def traversal(self):
        if self.head is None:
            print("Linked List is empty!!!")
        else:
            n=self.head
            while n is not None:
                print(n.data,"-->",end="")
                n=n.ref
    def add_begin(self,data):
        new_node=Node(data)
        new_node.ref=self.head
        self.head=new_node       
    def add_end(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
        else:
            n=self.head
            while(n.ref is not None):
                n=n.ref
            n.ref=new_node
    def after_node(self,data,x):
        if self.head is None:
            print("Linked list is empty!!!")
            return
        n=self.head
        while n is not None:
            if n.data==x:
                break
            else:
                n=n.ref
        if n is None:
            print("Node is not pesent in LL")
        else:
            new_node=Node(data)
            new_node.ref=n.ref
            n.ref=new_node
    def before_node(self,data,x):
        if self.head is None:
            print("Linked list is empty!!!")
            return
        #checking x is matching with first node
        if self.head.data==x:
            new_node=Node(data)
            new_node.ref=self.head
            self.head=new_node
            return
        #finding x previous node
        n=self.head
        while n.ref is not None:
            if n.ref.data==x:
                break
            else:
                n=n.ref
        if n.ref is None:
            print("Node is not found!!")
        else:
            new_node=Node(data)
            new_node.ref=n.ref
            n.ref=new_node
                    
ll=Linked_list()
ll.add_begin(100)
ll.before_node(200,100)
ll.before_node(300,100)
ll.traversal()
# Out:
# 200 -->300 -->100 -->

# %%
#Removing element at the begining of the linked list
class Node:
    def __init__(self,data):
        self.data=data
        self.ref=None
class Linked_list():
    def __init__(self):
        self.head=None
    def traversal(self):
        if self.head is None:
            print("Linked List is empty!!!")
        else:
            n=self.head
            while n is not None:
                print(n.data,"-->",end="")
                n=n.ref
    def add_begin(self,data):
        new_node=Node(data)
        new_node.ref=self.head
        self.head=new_node       
    def add_end(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
        else:
            n=self.head
            while(n.ref is not None):
                n=n.ref
            n.ref=new_node
    def after_node(self,data,x):
        if self.head is None:
            print("Linked list is empty!!!")
            return
        n=self.head
        while n is not None:
            if n.data==x:
                break
            else:
                n=n.ref
        if n is None:
            print("Node is not pesent in LL")
        else:
            new_node=Node(data)
            new_node.ref=n.ref
            n.ref=new_node
    def before_node(self,data,x):
        if self.head is None:
            print("Linked list is empty!!!")
            return
        #checking x is matching with first node
        if self.head.data==x:
            new_node=Node(data)
            new_node.ref=self.head
            self.head=new_node
            return
        #finding x previous node
        n=self.head
        while n.ref is not None:
            if n.ref.data==x:
                break
            else:
                n=n.ref
        if n.ref is None:
            print("Node is not found!!")
        else:
            new_node=Node(data)
            new_node.ref=n.ref
            n.ref=new_node
    def del_begin(self):
        if self.head is None:
            print("Linked list is Empty!!!")
        else:
            self.head=self.head.ref
                    
ll=Linked_list()
ll.add_begin(100)
ll.add_begin(500)
ll.add_begin(500)
ll.del_begin()
ll.traversal()
# Out:
# 500 -->100 -->

# %%
#delete element at the end of linked list     
class Node:
    def __init__(self,data):
        self.data=data
        self.ref=None
class Linked_list():
    def __init__(self):
        self.head=None
    def traversal(self):
        if self.head is None:
            print("Linked List is empty!!!")
        else:
            n=self.head
            while n is not None:
                print(n.data,"-->",end="")
                n=n.ref
    def add_begin(self,data):
        new_node=Node(data)
        new_node.ref=self.head
        self.head=new_node       
    def add_end(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
        else:
            n=self.head
            while(n.ref is not None):
                n=n.ref
            n.ref=new_node
    def after_node(self,data,x):
        if self.head is None:
            print("Linked list is empty!!!")
            return
        n=self.head
        while n is not None:
            if n.data==x:
                break
            else:
                n=n.ref
        if n is None:
            print("Node is not pesent in LL")
        else:
            new_node=Node(data)
            new_node.ref=n.ref
            n.ref=new_node
    def before_node(self,data,x):
        if self.head is None:
            print("Linked list is empty!!!")
            return
        #checking x is matching with first node
        if self.head.data==x:
            new_node=Node(data)
            new_node.ref=self.head
            self.head=new_node
            return
        #finding x previous node
        n=self.head
        while n.ref is not None:
            if n.ref.data==x:
                break
            else:
                n=n.ref
        if n.ref is None:
            print("Node is not found!!")
        else:
            new_node=Node(data)
            new_node.ref=n.ref
            n.ref=new_node
    def del_begin(self):
        if self.head is None:
            print("Linked list is Empty!!!")
        else:
            self.head=self.head.ref
    def del_end(self):
        if self.head is None:
            print("Linked List is Empty!!!")
        else:
            #checking 1st position of linked list ref none or not
            
            if self.head.ref is None:
                self.head=None
                return
            #find out last second position of linked list
            n=self.head
            while n.ref is not None:
                if n.ref.ref is None:
                    break
                else:
                    n=n.ref
            n.ref=None
                
ll=Linked_list()
ll.add_begin(800)
ll.add_begin(800)
ll.del_end()
ll.traversal()
# Out:
# 800 -->

# %%
#delete element at the end of linked list     
class Node:
    def __init__(self,data):
        self.data=data
        self.ref=None
class Linked_list():
    def __init__(self):
        self.head=None
    def traversal(self):
        if self.head is None:
            print("Linked List is empty!!!")
        else:
            n=self.head
            while n is not None:
                print(n.data,"-->",end="")
                n=n.ref
    def add_begin(self,data):
        new_node=Node(data)
        new_node.ref=self.head
        self.head=new_node       
    def add_end(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
        else:
            n=self.head
            while(n.ref is not None):
                n=n.ref
            n.ref=new_node
    def after_node(self,data,x):
        if self.head is None:
            print("Linked list is empty!!!")
            return
        n=self.head
        while n is not None:
            if n.data==x:
                break
            else:
                n=n.ref
        if n is None:
            print("Node is not pesent in LL")
        else:
            new_node=Node(data)
            new_node.ref=n.ref
            n.ref=new_node
    def before_node(self,data,x):
        if self.head is None:
            print("Linked list is empty!!!")
            return
        #checking x is matching with first node
        if self.head.data==x:
            new_node=Node(data)
            new_node.ref=self.head
            self.head=new_node
            return
        #finding x previous node
        n=self.head
        while n.ref is not None:
            if n.ref.data==x:
                break
            else:
                n=n.ref
        if n.ref is None:
            print("Node is not found!!")
        else:
            new_node=Node(data)
            new_node.ref=n.ref
            n.ref=new_node
    def del_begin(self):
        if self.head is None:
            print("Linked list is Empty!!!")
        else:
            self.head=self.head.ref
    def del_end(self):
        if self.head is None:
            print("Linked List is Empty!!!")
        else:
            #checking 1st position of linked list ref none or not
            
            if self.head.ref is None:
                self.head=None
                return
            #find out last second position of linked list
            n=self.head
            while n.ref is not None:
                if n.ref.ref is None:
                    break
                else:
                    n=n.ref
            n.ref=None
    def del_m(self,x):
        if self.head is None:
            print("linked listt is empty!!!")
            return
        if self.head.data==x:
            self.head=self.head.ref
            return
        n=self.head
        while n.ref is not None:
            if n.ref.data==x:
                break
            else:
                n=n.ref
        if n.ref is None:
            print("Node not found!!!")
        else:
            n.ref=n.ref.ref
            
ll=Linked_list()
ll.add_begin(800)
ll.add_begin(10)
ll.add_begin(500)
ll.del_m(800)
ll.traversal()
# Out:
# 500 -->10 -->

# %%
#practise:
#add_begining
class Node:
    def __init__(self,data):
        self.data=data
        self.ref=None
class ll():
    def __init__(self):
        self.head=None
    def add_begin(self,data):
        new=Node(data)
        new.ref=self.head
        self.head=new
    def trv(self):
        if self.head is None:
            print("Linked List is empty!!")
        else:
            n=self.head
            while n is not None:
                print(n.data,"-->",end="")
                n=n.ref
    def add_end(self,data):
        if self.head is None:
            new=Node(data)
            self.head=new
            return
        n=self.head
        while n is not None:
            if n.ref is None:
                break
            else:
                n=n.ref
        new=Node(data)
        n.ref=new
                
    def add_before(self,data,x):
        if self.head is None:
            print("ll is empty!!")
            return
        if self.head.data==x:
            new=Node(data)
            new.ref=self.head
            self.head=new
            return
        n=self.head
        while n.ref is not None:
            if n.ref.data==x:
                break
            else:
                n=n.ref
        if n.ref is None:
            print("Not Found!!")
        else:
            new=Node(data)
            new.ref=n.ref
            n.ref=new
            
    def add_after(self,data,x):
        if self.head is None:
            print("ll is empty!!")
            return
        n=self.head
        while n is not None:
            if n.data==x:
                break
            else:
                n=n.ref
        if n is None:
            print("Not found!!")
        else:
            new=Node(data)
            new.ref=n.ref
            n.ref=new 
    def del_b(self):
        if self.head is None:
            print("ll is empty!!")
            return
        self.head=self.head.ref
    def del_e(self):
        if self.head is None:
            print("ll is empty!!")
            return
        if self.head.ref is None:
            self.head=None
        n=self.head
        while n.ref is not None:
            if n.ref.ref is None:
                break
            else:
                n=n.ref
        if n.ref is None:
            print("Not found!!")
        else:
            n.ref=None
    def del_m(self,x):
        if self.head is None:
            print("ll is empty!!")
            return
        if self.head.data==x:
            self.head=self.head.ref
            return
        n=self.head
        while n.ref is not None:
            if n.ref.data==x:
                break
            else:
                n=n.ref
        if n.ref is None:
            print("not found!!!")
        else:
            n.ref=n.ref.ref
l=ll()
#l.add_end(20)
l.add_end(30)
l.del_m(30)
l.trv()
# Out:
# Linked List is empty!!

# %%
#practice2
class Node:
    def __init__(self,data):
        self.data=data
        self.ref=None
class ll():
    def __init__(self):
        self.head=None
    def traversal(self):
        if self.head is None:
            print("Linked List is Empty!!")
        else:
            n=self.head
            while n is not None:
                print(n.data,"-->",end="")
                n=n.ref
    def add_begin(self,data):
        new_node=Node(data)
        new_node.ref=self.head
        self.head=new_node
    def add_end(self,data):
        new_node=Node(data)
        if self.head is None:
            new_node.ref=self.head
            self.head=new_node
            return
        n=self.head
        while n.ref is not None:
            n=n.ref
        n.ref=new_node
    def add_before(self,data,x):
        if self.head is None:
            print("Linked list is Empty!!!")
            return
        if self.head.data==x:
            new_node=Node(data)
            new_node.ref=self.head
            self.head=new_node
            return
        n=self.head
        while n.ref is not None:
            if n.ref.data==x:
                break
            else:
                n=n.ref
        if n.ref is None:
            print("Node not found!!!")
        else:
            new_node=Node(data)
            new_node.ref=n.ref
            n.ref=new_node
        
    def add_After(self,data,x):
        if self.head is None:
            print("Linked list is Empty!!!")
            return
        else:
            n=self.head
            while n is not None:
                if n.data==x:
                    break
                else:
                    n=n.ref
            if n is None:
                print("Node not found!!!")
            else:
                new_node=Node(data)
                new_node.ref=n.ref
                n.ref=new_node
    def d_b(self):
        if self.head is None:
            print("Linked list is Empty!!!")
        else:
            self.head=self.head.ref
            #self.head.ref=self.head 
    def d_end(self):
        if self.head is None:
            print("Linked list is Empty!!!")
            return
        elif self.head.ref is None:
            self.head=None
        else:
            n=self.head
            while n is not None:
                if n.ref.ref is None:
                    break
                else:
                    n=n.ref
            n.ref=None
    def d_m(self,x):
        if self.head is None:
            print("Linked list is Empty!!!")
            return
        elif self.head.data==x:
            self.head=self.head.ref
        else:
            n=self.head
            while n.ref is not None:
                if n.ref.data==x:
                    break
                else:
                    n=n.ref
            if n.ref is None:
                print("Node not found!!!")
            else:
                n.ref=n.ref.ref
                
l=ll()

l.add_begin(100)
l.add_begin(200)
l.add_begin(300)
l.add_After(8,300)
l.add_After(80,300)
l.add_After(80,100)
l.traversal()
# Out:
# 300 -->80 -->8 -->200 -->100 -->80 -->
