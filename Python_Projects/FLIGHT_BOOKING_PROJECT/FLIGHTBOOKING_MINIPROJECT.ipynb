# %% [markdown]
# # FLIGHTBOOKING_MINIPROJECT

# %%
from FLIGHTBOOKING_PROJECT_DATATYPES import *
i=True
while i:
    print('----------------------------------------------------')
    print("*****CHENNAI TO HYDERABAD FLIGHT BOOKING CENTER*****")
    print('----------------------------------------------------')
    print("1.Ticket Booking")
    print("2.Ticket Cancellation")
    print("3.Exit")
    print("4.ADMIN")
    print('----------------------------------------------------')
    try:
        inp=int(input("Please select Any one option:"))
    except (ValueError): 
        print(f"Please select above metioned optios.such a option nnot available here")
    else:
        if(inp==1 or inp==2 or inp==3 or inp==4):
            if(inp==1):
                print('-'*100)
                print("There Are two Flights are available here:(101,102)")
                print('101-AirIndia-Morning 8AM')
                print('102-Indigo-Night 8PM')
                print('-'*100)
                flight=int(input("Please select the Flights:(101,102)"))
                if(flight==101):
                    Available_buiness_seats=len(business_seats)
                    Available_economy_seats=len(economy_seats)
                    print('_'*100)
                    print("AVAILABLE BUSINESS CLASS SEATS:",Available_buiness_seats)
                    print("AVAILABLE ECONOMY CLASS SEATS:",Available_economy_seats)
                    print('_'*100)
                    Name=input("Please Enter your Name:")
                    Class=input("Select your Travelling class:(BUSINESS/Economy)")
                    if(Class.lower()=='business'):
                        if(len(business_seats)>0):
                            list1=[business_seats[l] for l in range(0,Available_buiness_seats)]
                            print('='*100)
                            print(list1)
                            print('='*100)
                            Business_seat_selection=input("Please select the seats like a (A-1,A-2):")
                            Business_seat_selection1=list(Business_seat_selection.split(','))
                            Business_seat_selection1_set=set(Business_seat_selection1)
                            if all(seat in business_seats for seat in Business_seat_selection1):
                                if (len(Business_seat_selection1)==len(Business_seat_selection1_set)):
                                    food=input("Do you want to add FOOD with your ticket:(Y/N)")
                                    if food.lower()=='y':
                                        food_money=300*len(Business_seat_selection1)
                                    else:
                                        food_money=0
                                    if(len(Business_seat_selection1)<=6 and len(Business_seat_selection1)<=Available_buiness_seats ):
                                        import random,string
                                        s=string.digits
                                        id=int(''.join(random.sample(s,4)))
                                        if business_increment[0]==2:
                                            print("Ticket rate is increase 200 ruppes evry successfull booking!!!!This is second booking so we added 200")
                                            print("1 seat rate is 2200 rupees")
                                            rate=(200+2000)*len(Business_seat_selection1)
                                        elif business_increment[0]==3:
                                            print("Ticket rate is increase 200 ruppes evry successfull booking!!!!This is Third booking so we added 400")
                                            print("1 seat rate is 2400 rupees")
                                            rate=(400+2000)*len(Business_seat_selection1)
                                        elif business_increment[0]==4:
                                            print("Ticket rate is increase 200 ruppes evry successfull booking!!!!This is Fourth booking so we added 600")
                                            print("1 seat rate is 2600 rupees")
                                            rate=(600+2000)*len(Business_seat_selection1)
                                        elif business_increment[0]==5:
                                            print("Ticket rate is increase 200 ruppes evry successfull booking!!!!This is fifth booking so we added 800")
                                            print("1 seat rate is 2800 rupees")
                                            rate=(800+2000)*len(Business_seat_selection1)
                                        elif business_increment[0]==1:
                                            print("1 seat rate is 2000 rupees")
                                            rate=2000*len(Business_seat_selection1)
                                        else:
                                            print("Ticket rate is increase 200 ruppes evry successfull booking!!!!Maximum today booking completed so we added 1000")
                                            print("1 seat rate is 3000 rupees")
                                            rate=(1000+2000)*len(Business_seat_selection1)
                                        print("YOUR TOTAL TICKET RATE IS:",rate)
                                        if(food_money>0):
                                            print("one person food rate is:300")
                                            print(f"YOUR {len(Business_seat_selection1)} person food RATE IS:{food_money}")
                                        else:
                                            print("you have not selected food so no food fees added in your amount...")
                                        total_payment=rate+food_money
                                        print('='*100)
                                        print("Total You payable money is:",total_payment)
                                        print('='*100)
                                        pay=int(input("Please enter your Amount Here:"))
                                        if(pay==total_payment):
                                            dic.update({id:'{},{},{},{},{}'.format(Name,flight,pay,"business",Business_seat_selection)})
                                            for i in Business_seat_selection1:
                                                business_seats.remove(i)
                                            Available_buiness_seats=len(business_seats)
                                            print('='*100)
                                            print(f"{len(Business_seat_selection1)} Seat has been booked!!! HAPPY JOURNEY {Name}.")
                                            print("Your Booking id is:",id)
                                            print('='*100)
                                            #print(dic)
                                            del business_increment[0]
                                        else:
                                            print("please enter correct amount")
                                    else:
                                        print("sorry we don't have a seats to give you")
                                else:
                                    print("YOU ENTERED SAME SEAT MORE THAN ONE TIME!!! Please check...")
                            else:
                                print("please enter above mentioned available seats")
                        else:
                            print("No Seats available in business class")
                    elif(Class.lower()=='economy'):
                        if(len(economy_seats)>0):
                            list1=[economy_seats[l] for l in range(0,Available_economy_seats)]
                            print('#'*100)
                            print("AVAILABLE SEATS:",list1)
                            print('#'*100)
                            economy_seat_selection=input("Please select the seats like a (B-1,C-2):")
                            economy_seat_selection1=list(economy_seat_selection.split(','))
                            economy_seat_selection1_set=set(economy_seat_selection1)
                            if all(seat in economy_seats for seat in economy_seat_selection1):
                                if(len(economy_seat_selection1)==len(economy_seat_selection1_set)):
                                    food=input("Do you want to add FOOD with your ticket:(Y/N)")
                                    if food.lower()=='y':
                                        food_money=200*len(economy_seat_selection1)
                                    else:
                                        food_money=0
                                    if(len(economy_seat_selection1)<=12 and len(economy_seat_selection1)<=Available_economy_seats ):
                                        import random,string
                                        s=string.digits
                                        id=int(''.join(random.sample(s,4)))
                                        if economy_increment[0]==2:
                                            print("Ticket rate is increase 100 ruppes evry successfull booking!!!! This is Second booking so we added 100 extra")
                                            print("1 seat rate is 1100 rupees")
                                            rate=(100+1000)*len(economy_seat_selection1)
                                        elif economy_increment[0]==3:
                                            print("Ticket rate is increase 100 ruppes evry successfull booking!!!! This is Third booking so we added 200 extra")
                                            print("1 seat rate is 1200 rupees")
                                            rate=(200+1000)*len(economy_seat_selection1)
                                        elif economy_increment[0]==4:
                                            print("Ticket rate is increase 100 ruppes evry successfull booking!!!! This is Fourth booking so we added 300 extra")
                                            print("1 seat rate is 1300 rupees")
                                            rate=(300+1000)*len(economy_seat_selection1)
                                        elif economy_increment[0]==5:
                                            print("Ticket rate is increase 100 ruppes evry successfull booking!!!! This is Fifth booking so we added 400 extra")
                                            print("1 seat rate is 1400 rupees")
                                            rate=(400+1000)*len(economy_seat_selection1)
                                        elif economy_increment[0]==6:
                                            print("Ticket rate is increase 100 ruppes evry successfull booking!!!! This is Sixth booking so we added 500 extra")
                                            print("1 seat rate is 1500 rupees")
                                            rate=(500+1000)*len(economy_seat_selection1)
                                        elif economy_increment[0]==7:
                                            print("Ticket rate is increase 100 ruppes evry successfull booking!!!! This is Seventh booking so we added 600 extra")
                                            print("1 seat rate is 1600 rupees")
                                            rate=(600+1000)*len(economy_seat_selection1)
                                        elif economy_increment[0]==8:
                                            print("Ticket rate is increase 100 ruppes evry successfull booking!!!! This is eightth booking so we added 700 extra")
                                            print("1 seat rate is 1700 rupees")
                                            rate=(700+1000)*len(economy_seat_selection1)
                                        elif economy_increment[0]==9:
                                            print("Ticket rate is increase 100 ruppes evry successfull booking!!!! This is nineth booking so we added 800 extra")
                                            print("1 seat rate is 1800 rupees")
                                            rate=(800+1000)*len(economy_seat_selection1)
                                        elif economy_increment[0]==10:
                                            print("Ticket rate is increase 100 ruppes evry successfull booking!!!! This is tenth booking so we added 900 extra")
                                            print("1 seat rate is 1900 rupees")
                                            rate=(900+1000)*len(economy_seat_selection1)
                                        elif economy_increment[0]==1:
                                            print("1 seat rate is 1000 rupees")
                                            rate=1000*len(economy_seat_selection1)
                                        else:
                                            print("Ticket rate is increase 100 ruppes evry successfull booking!!!!Maximum booking completed so we added 1000 extra")
                                            print("1 seat rate is 2000 rupees")
                                            rate=(1000+1000)*len(economy_seat_selection1)
                                        print("YOUR TOTAL TICKET AMOUNT IS:",rate)
                                        if(food_money>0):
                                            print("(One person food rate is:200)")
                                            print(f"YOUR {len(economy_seat_selection1)} person food RATE IS:{food_money}")
                                        else:
                                            print("you have not selected food so no food fees added in your amount...")
                                        total_payment=rate+food_money
                                        print('='*100)
                                        print("Total You payable money is:",total_payment)
                                        print('='*100)
                                        pay=int(input("Please enter your Amount Here:"))
                                        if(pay==total_payment):
                                            dic.update({id:'{},{},{},{},{}'.format(Name,flight,pay,"economy",economy_seat_selection)})
                                            for i in economy_seat_selection1:
                                                economy_seats.remove(i)
                                            Available_economy_seats=len(economy_seats)
                                            print('='*100)
                                            print(f"{len(economy_seat_selection1)} Seat has been booked!!! HAPPY JOURNEY {Name}.")
                                            print("Your Booking id is:",id)
                                            print('='*100)
                                            #print(dic)
                                            del economy_increment[0]
                                        else:
                                            print("please enter correct amount")
                                    else:
                                        print("sorry we don't have a seats to give you")
                                else:
                                    print("YOU ENTERED SAME SEAT MORE THAN ONE TIME!!! Please check...")
                            else:
                                print("please enter above mentioned available seats")
                        else:
                            print("No Seats available in business class")
                    else:
                        print("Please Choose correct class")
                elif flight==102:
                    Available_buiness_seats_102=len(business_seats_102)
                    Available_economy_seats_102=len(economy_seats_102)
                    print('_'*100)
                    print("AVAILABLE BUSINESS CLASS SEATS:",Available_buiness_seats_102)
                    print("AVAILABLE ECONOMY CLASS SEATS:",Available_economy_seats_102)
                    print('_'*100)
                    Name=input("Please Enter your Name:")
                    Class=input("Select your Travelling class:(BUSINESS/Economy)")
                    if(Class.lower()=='business'):
                        if(len(business_seats_102)>0):
                            list1=[business_seats_102[l] for l in range(0,Available_buiness_seats_102)]
                            print('='*100)
                            print(list1)
                            print('='*100)
                            Business_seat_selection_102=input("Please select the seats like a (A-1,A-2):")
                            Business_seat_selection1_102=list(Business_seat_selection_102.split(','))
                            Business_seat_selection1_102_set=set(Business_seat_selection1_102)
                            if all(seat in business_seats_102 for seat in Business_seat_selection1_102):
                                if(len(Business_seat_selection1_102)==len(Business_seat_selection1_102_set)):
                                    food=input("Do you want to add FOOD with your ticket:(Y/N)")
                                    if food.lower()=='y':
                                        food_money=300*len(Business_seat_selection1_102)
                                    else:
                                        food_money=0
                                    if(len(Business_seat_selection1_102)<=6 and len(Business_seat_selection1_102)<=Available_buiness_seats_102):
                                        import random,string
                                        s=string.digits
                                        id=int(''.join(random.sample(s,4)))
                                        if business_increment_102[0]==2:
                                            print("Ticket rate is increase 200 ruppes evry successfull booking!!!!This is second booking so we added 200")
                                            print("1 seat rate is 2200 rupees")
                                            rate=(200+2000)*len(Business_seat_selection1_102)
                                        elif business_increment_102[0]==3:
                                            print("Ticket rate is increase 200 ruppes evry successfull booking!!!!This is Third booking so we added 400")
                                            print("1 seat rate is 2400 rupees")
                                            rate=(400+2000)*len(Business_seat_selection1_102)
                                        elif business_increment_102[0]==4:
                                            print("Ticket rate is increase 200 ruppes evry successfull booking!!!!This is Foruth booking so we added 600")
                                            print("1 seat rate is 2600 rupees")
                                            rate=(600+2000)*len(Business_seat_selection1_102)
                                        elif business_increment_102[0]==5:
                                            print("Ticket rate is increase 200 ruppes evry successfull booking!!!!This is Fifth booking so we added 800")
                                            print("1 seat rate is 2800 rupees")
                                            rate=(800+2000)*len(Business_seat_selection1_102)
                                        elif business_increment_102[0]==1:
                                            print("1 seat rate is 2000 rupees")
                                            rate=2000*len(Business_seat_selection1_102)
                                        else:
                                            print("Ticket rate is increase 200 ruppes evry successfull booking!!!Maximum booking completed so we added 1000")
                                            print("1 seat rate is 3000 rupees")
                                            rate=(1000+2000)*len(Business_seat_selection1_102)
                                        print("YOUR TOTAL TICKET RATE IS:",rate)
                                        if(food_money>0):
                                            print("(one person food rate is:300)")
                                            print(f"YOUR {len(Business_seat_selection1_102)} person food RATE IS:{food_money}")
                                        else:
                                            print("you have not selected food so no food fees added in your amount...")
                                        total_payment=rate+food_money
                                        print('='*100)
                                        print("Total You payable money is:",total_payment)
                                        print('='*100)
                                        pay=int(input("Please enter your Amount Here:"))
                                        if(pay==total_payment):
                                            dic.update({id:'{},{},{},{},{}'.format(Name,flight,pay,"business",Business_seat_selection_102)})
                                            for i in Business_seat_selection1_102:
                                                business_seats_102.remove(i)
                                            Available_buiness_seats_102=len(business_seats_102)
                                            print('='*100)
                                            print(f"{len(Business_seat_selection1_102)} Seat has been booked!!! HAPPY JOURNEY {Name}.")
                                            print("Your Booking id is:",id)
                                            print('='*100)
                                            #print(dic)
                                            del business_increment_102[0]
                                        else:
                                            print("please enter correct amount")
                                    else:
                                        print("sorry we don't have a seats to give you")
                                else:
                                    print("YOU ENTERED SAME SEAT MORE THAN ONE TIME!!! Please check...")
                            else:
                                print("please enter above mentioned available seats")
                        else:
                            print("No Seats available in business class")
                    
                    elif(Class.lower()=='economy'):
                        if(len(economy_seats_102)>0):
                            list1=[economy_seats_102[l] for l in range(0,Available_economy_seats_102)]
                            print('#'*100)
                            print("AVAILABLE SEATS:",list1)
                            print('#'*100)
                            economy_seat_selection_102=input("Please select the seats like a (B-1,C-2):")
                            economy_seat_selection1_102=list(economy_seat_selection_102.split(','))
                            economy_seat_selection1_102_set=set(economy_seat_selection1_102)
                            if all(seat in economy_seats_102 for seat in economy_seat_selection1_102):
                                if(len(economy_seat_selection1_102)==len(economy_seat_selection1_102_set)):
                                    food=input("Do you want to add FOOD with your ticket:(Y/N)")
                                    if food.lower()=='y':
                                        food_money=200*len(economy_seat_selection1_102)
                                    else:
                                        food_money=0
                                    if(len(economy_seat_selection1_102)<=12 and len(economy_seat_selection1_102)<=Available_economy_seats_102):
                                        import random,string
                                        s=string.digits
                                        id=int(''.join(random.sample(s,4)))
                                        if economy_increment_102[0]==2:
                                            print("Ticket rate is increase 100 ruppes evry successfull booking!!!! This is Second booking so we added 100 extra")
                                            print("1 seat rate is 1100 rupees")
                                            rate=(100+1000)*len(economy_seat_selection1_102)
                                        elif economy_increment_102[0]==3:
                                            print("Ticket rate is increase 100 ruppes evry successfull booking!!!! This is Third booking so we added 200 extra")
                                            print("1 seat rate is 1200 rupees")
                                            rate=(200+1000)*len(economy_seat_selection1_102)
                                        elif economy_increment_102[0]==4:
                                            print("Ticket rate is increase 100 ruppes evry successfull booking!!!! This is Fourth booking so we added 300 extra")
                                            print("1 seat rate is 1300 rupees")
                                            rate=(300+1000)*len(economy_seat_selection1_102)
                                        elif economy_increment_102[0]==5:
                                            print("Ticket rate is increase 100 ruppes evry successfull booking!!!! This is Fifth booking so we added 400 extra")
                                            print("1 seat rate is 1400 rupees")
                                            rate=(400+1000)*len(economy_seat_selection1_102)
                                        elif economy_increment_102[0]==6:
                                            print("Ticket rate is increase 100 ruppes evry successfull booking!!!! This is Sixth booking so we added 500 extra")
                                            print("1 seat rate is 1500 rupees")
                                            rate=(500+1000)*len(economy_seat_selection1_102)
                                        elif economy_increment_102[0]==7:
                                            print("Ticket rate is increase 100 ruppes evry successfull booking!!!! This is Seventh booking so we added 600 extra")
                                            print("1 seat rate is 1600 rupees")
                                            rate=(600+1000)*len(economy_seat_selection1_102)
                                        elif economy_increment_102[0]==8:
                                            print("Ticket rate is increase 100 ruppes evry successfull booking!!!! This is Eighth booking so we added 700 extra")
                                            print("1 seat rate is 1700 rupees")
                                            rate=(700+1000)*len(economy_seat_selection1_102)
                                        elif economy_increment_102[0]==9:
                                            print("Ticket rate is increase 100 ruppes evry successfull booking!!!! This is Nineth booking so we added 800 extra")
                                            print("1 seat rate is 1800 rupees")
                                            rate=(800+1000)*len(economy_seat_selection1_102)
                                        elif economy_increment_102[0]==10:
                                            print("Ticket rate is increase 100 ruppes evry successfull booking!!!! This is tenth booking so we added 900 extra")
                                            print("1 seat rate is 1900 rupees")
                                            rate=(900+1000)*len(economy_seat_selection1_102)
                                        elif economy_increment_102[0]==1:
                                            print("1 seat rate is 1000 rupees")
                                            rate=1000*len(economy_seat_selection1_102)
                                        else:
                                            print("Ticket rate is increase 100 ruppes evry successfull booking!!!! Maximum booking completed so we added 1000 extra")
                                            print("1 seat rate is 2000 rupees")
                                            rate=(1000+1000)*len(economy_seat_selection1_102)
                                        
                                        print("YOUR TOTAL TICKET AMOUNT IS:",rate)
                                        if(food_money>0):
                                            print("(One person food rate is:200)")
                                            print(f"YOUR {len(economy_seat_selection1_102)} person food RATE IS:{food_money}")
                                        else:
                                            print("you have not selected food so no food fees added in your amount...")
                                        total_payment=rate+food_money
                                        print('='*100)
                                        print("Total You payable money is:",total_payment)
                                        print('='*100)
                                        pay=int(input("Please enter your Amount Here:"))
                                        if(pay==total_payment):
                                            dic.update({id:'{},{},{},{},{}'.format(Name,flight,pay,"economy",economy_seat_selection_102)})
                                            for i in economy_seat_selection1_102:
                                                economy_seats_102.remove(i)
                                            Available_economy_seats_102=len(economy_seats_102)
                                            print('='*100)
                                            print(f"{len(economy_seat_selection1_102)} Seat has been booked!!! HAPPY JOURNEY {Name}.")
                                            print("Your Booking id is:",id)
                                            print('='*100)
                                            #print(dic)
                                            del economy_increment_102[0]
                                        else:
                                            print("please enter correct amount")
                                    else:
                                        print("sorry we don't have a seats to give you")
                                else:
                                    print("YOU ENTERED SAME SEAT MORE THAN ONE TIME!!! Please check...")
                            else:
                                print("please enter above mentioned available seats")
                        else:
                            print("No Seats available in business class")
                    else:
                        print("Please Choose correct class")
                else:
                    print("Please Enter Correct Flight number")
            elif(inp==2):
                cancellation_id=int(input("Enter your Correct ID:"))
                keys1=dic.keys()    
                if(cancellation_id in keys1):
                    ss=str(dic[cancellation_id])
                    ll=ss.split(',')
                    SEATS=ll[4:]
                    print('-'*100)
                    print("NAME:",ll[0])
                    print("FLIGHT:",ll[1])
                    print("PAIDAMONT:",ll[2])
                    print("CLASS:",ll[3])
                    print("SEATS:",SEATS)
                    print('-'*100)
                    #print(ll)
                    YES_NO=input("ABOVE MENTIONED ALL YOUR DETAILS ARE CORRECT(Y/N):")
                    if YES_NO.lower()=='y':
                        LENGTH_SEATS=len(SEATS)
                        print('#'*100)
                        print(f"you had been booked {LENGTH_SEATS} seats.",SEATS)
                        print('#'*100)
                        choi=input("Please enter only you booked Seat for cancellation:")
                        choice=list(choi.split(','))
                        choice_set=set(choice)
                        if all(se in SEATS for se in choice):
                            if(len(choice)==len(choice_set)):
                                if((ll[1]=='101') and (ll[3]=='business')):
                                    sss=choi.split(',')
                                    print("Cancellation fee is 200")
                                    print(f"{len(sss)} seat has been cancelled")
                                    print(f"Remaining {int(ll[2])-(len(sss)*200)} will be deposited your account soon")
                                    business_increment.append(7)
                                    for m in sss:
                                        business_seats.append(m)
                                    if(len(SEATS)==len(choice)):
                                        del dic[cancellation_id]
                                    else:
                                        lli=[]
                                        for k1 in SEATS:
                                            if(k1 not in choice):
                                                lli.append(k1)
                                
                                        dic[cancellation_id]='{},{},{},{},{}'.format(ll[0],ll[1],int(ll[2])-(len(sss)*200),ll[3],','.join(lli))
                                        
                                elif ((ll[1] == '101') and (ll[3] == 'economy')):
                                    sss=choi.split(',')
                                    print("Cancellation fee is 200")
                                    print(f"{len(sss)} seat has been cancelled")
                                    print(f"Remaining {int(ll[2])-(len(sss)*200)} will be deposited your account soon")
                                    economy_increment.append(13)
                                    for m in sss:
                                        economy_seats.append(m)
                                    if(len(SEATS)==len(choice)):
                                        del dic[cancellation_id]
                                    else:
                                        lli=[]
                                        for k1 in SEATS:
                                            if(k1 not in choice):
                                                lli.append(k1)
                                
                                        dic[cancellation_id]='{},{},{},{},{}'.format(ll[0],ll[1],int(ll[2])-(len(sss)*200),ll[3],','.join(lli))
                                    
                                elif(ll[1]=='102' and ll[3]=='business'):
                                    sss=choi.split(',')
                                    print("Cancellation fee is 200")
                                    print(f"{len(sss)} seat has been cancelled")
                                    print(f"Remaining {int(ll[2])-(len(sss)*200)} will be deposited your account soon")
                                    business_increment_102.append(7)
                                    for m in sss:
                                        business_seats_102.append(m)
                                    if(len(SEATS)==len(choice)):
                                        del dic[cancellation_id]
                                    else:
                                        lli=[]
                                        for k1 in SEATS:
                                            if(k1 not in choice):
                                                lli.append(k1)
                                        dic[cancellation_id]='{},{},{},{},{}'.format(ll[0],ll[1],int(ll[2])-(len(sss)*200),ll[3],','.join(lli))
                                else:
                                    sss=choi.split(',')
                                    print("Cancellation fee is 200")
                                    print(f"{len(sss)} seat has been cancelled")
                                    print(f"Remaining {int(ll[2])-(len(sss)*200)} will be deposited your account soon")
                                    economy_increment_102.append(13)
                                    for m in sss:
                                        economy_seats_102.append(m)
                                    if(len(SEATS)==len(choice)):
                                        del dic[cancellation_id]
                                    else:
                                        lli=[]
                                        for k1 in SEATS:
                                            if(k1 not in choice):
                                                lli.append(k1)
                                        dic[cancellation_id]='{},{},{},{},{}'.format(ll[0],ll[1],int(ll[2])-(len(sss)*200),ll[3],','.join(lli))
                            else:
                                print("YOU ENTERED SAME SEAT MORE THAN ONE TIME!!! Please check...")
                        else:
                            print("Please enter above metioned you booked seat")
                    else:
                        print("Sorry for the wrong information!!!please check with admin")
                else:
                    print("Please enter correct ID")
            elif(inp==4):
                try:
                    passcode=int(input("Enter your secret passcode:"))
                except ValueError:
                    print("PLEASE ENTER NUMERIC NUMBER")
                if(passcode==9999):
                    print()
                    keys=dic.keys()
                    import csv
                    fields=['ID','NAME','FLIGHT','SEATS',"PAID_AMOUNT",'CLASS']
                    with open('E:/PYTHON/FILE/FLIGHTBOOKIN_MINIPROJECT_DATABASE.csv','w+') as f:
                        w=csv.writer(f)
                        w.writerow(fields)
                        for o in keys:
                            s=str(o)+','
                            st=s+dic[o]
                            data=st.split(',')
                            w.writerow(data)
                        f.seek(0,0)
                        print(f.read())
                       #print(dic)
                else:
                    print("please Enter correct passcode")
            else:
                i=False
        else:
            print(f"Please select above metioned optios.you enter{inp}.such a option not available here")
# Out:
# ----------------------------------------------------
# *****CHENNAI TO HYDERABAD FLIGHT BOOKING CENTER*****
# ----------------------------------------------------
# 1.Ticket Booking
# 2.Ticket Cancellation
# 3.Exit
# 4.ADMIN
# ----------------------------------------------------
# Please select Any one option:1
# ----------------------------------------------------------------------------------------------------
# There Are two Flights are available here:(101,102)
# 101-AirIndia-Morning 8AM
# 102-Indigo-Night 8PM
# ----------------------------------------------------------------------------------------------------
# Please select the Flights:(101,102)101
# ____________________________________________________________________________________________________
# AVAILABLE BUSINESS CLASS SEATS: 6
# AVAILABLE ECONOMY CLASS SEATS: 12
# ____________________________________________________________________________________________________
# Please Enter your Name:karthik
# ...
