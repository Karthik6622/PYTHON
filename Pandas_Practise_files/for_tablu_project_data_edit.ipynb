# %%
import pandas as pd

# %%
dd=pd.read_excel("E:\\2022_IOB_STATEMENT.xls")
dd
# Out:
#              Date (Value Date)  \
# 0    01-Jan-2022 (01-Jan-2022)
# 1    01-Jan-2022 (01-Jan-2022)
# 2    02-Jan-2022 (02-Jan-2022)
# 3    03-Jan-2022 (03-Jan-2022)
# 4    16-Jan-2022 (16-Jan-2022)
# ..                         ...
# 352  30-Dec-2022 (31-Dec-2022)
# 353  30-Dec-2022 (31-Dec-2022)
# 354  30-Dec-2022 (31-Dec-2022)
# 355  31-Dec-2022 (31-Dec-2022)
# 356  31-Dec-2022 (31-Dec-2022)
#
#                                            Particulars Ref No./Cheque No  \
# 0    UPI/200194098877/DR/C H D ATTATREYA/PYT/Oid202201         S55469220
# 1                UPI/200101119353/CR/KARTH IK R/UTI/NA         S56425782
# 2    UPI/200254824894/DR/SAMMA NA RAMANAIAH/UBI/Pay...         S61062115
# 3    UPI/200367577750/CR/ABHIS HEK  SENTHIL/SBI/Pay...         S68514199
# 4                UPI/201646643715/CR/KARTH IK R/UTI/NA         S43899395
# ..                                                 ...               ...
# ...

# %%
dd['Date (Value Date)']=dd['Date (Value Date)'].apply(lambda x:x.split('(')[0])

# %%
dd
# Out:
#     Date (Value Date)                                        Particulars  \
# 0        01-Jan-2022   UPI/200194098877/DR/C H D ATTATREYA/PYT/Oid202201
# 1        01-Jan-2022               UPI/200101119353/CR/KARTH IK R/UTI/NA
# 2        02-Jan-2022   UPI/200254824894/DR/SAMMA NA RAMANAIAH/UBI/Pay...
# 3        03-Jan-2022   UPI/200367577750/CR/ABHIS HEK  SENTHIL/SBI/Pay...
# 4        16-Jan-2022               UPI/201646643715/CR/KARTH IK R/UTI/NA
# ..                ...                                                ...
# 352      30-Dec-2022               UPI/236503185539/DR/KARTH IK R/UTI/NA
# 353      30-Dec-2022       UPI/236503200674/DR/Marit hangam Ravik/IDI/NA
# 354      30-Dec-2022               UPI/236503208723/CR/KARTH IK R/UTI/NA
# 355      31-Dec-2022   ECOM-Payu Payments Pvt lt d Gurgaon IN-V218397...
# 356      31-Dec-2022               UPI/236513042972/CR/KARTH IK R/UTI/NA
#
#     Ref No./Cheque No Transaction Type Debit(Rs) Credit(Rs)  Balance (Rs)
# ...

# %%
dd.to_excel('E:\Tableau\2022_IOB_STATEMENT.xlsx')
